# %%
# =========================================
# Script: advanced_spectral_analysis-JADES.py
# Purpose: JADES data download, processing, emission line analysis, and plotting.
# Author: Joseph Havens
# Research Supervisor: Dr. Bren Backhaus
# Date: 31-08-2025
# =========================================

import os
import shutil
import logging
from datetime import datetime
from collections import defaultdict
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from scipy.signal import savgol_filter, find_peaks, medfilt
from scipy.optimize import curve_fit
from itertools import cycle
import time

# Astropy imports for more robust astronomical data handling
import astropy.units as u
from astropy.visualization import quantity_support
import astropy.constants as const
from astropy.io import fits
from astropy.table import Table
from astropy.utils.data import download_file
from astropy.stats import sigma_clip
from astropy.wcs import FITSFixedWarning
import warnings
from astropy.utils.exceptions import AstropyDeprecationWarning
from astropy.modeling.fitting import FittingWithOutlierRemoval
from scipy.optimize import OptimizeWarning

try:
  from specutils import Spectrum1D, SpectralRegion
  from specutils.manipulation import extract_region
  from specutils.fitting import fit_generic_continuum, fit_lines
  from specutils.analysis import template_correlate
except:
  # !pip install --upgrade specutils astropy
  from specutils import Spectrum1D, SpectralRegion
  from specutils.manipulation import extract_region
  from specutils.fitting import fit_generic_continuum, fit_lines
  from specutils.analysis import template_correlate

from astropy.modeling.models import Gaussian1D, Chebyshev1D
from astropy.nddata import StdDevUncertainty

warnings.simplefilter('ignore', category=AstropyDeprecationWarning)
warnings.simplefilter('ignore', category=UserWarning) # Catches the "Model is linear" warning
warnings.simplefilter('ignore', category=RuntimeWarning) # Catches the "overflow" warning
warnings.simplefilter('ignore', category=OptimizeWarning) # Catches "The fit may be unsuccessful"

# %%
# Suppress a common but benign FITS warning
warnings.filterwarnings('ignore', category=FITSFixedWarning)

# --- Configuration Section ---

# 1. Define paths
# Use os.path.join for cross-platform compatibility.
USER_HOME = "/content/drive/MyDrive/Bren_code/My_work/"
BASE_PATH = os.path.join(USER_HOME, "JADES_Analysis/")
SAVE_PATH = os.path.join(BASE_PATH, "JADES/1180")
TARGET_LIST_PATH = os.path.join(BASE_PATH, "jades.csv") # Assumes the CSV is in the base path
OUTPUT_CATALOG_PATH = os.path.join(BASE_PATH, "jades_line_flux_catalog.csv")
PLOT_PATH = os.path.join(BASE_PATH, "plots/")

# 2. Data source
JADES_PROJECTS = {
    '1180': {
        'jades-gds-wide-v3': 'https://s3.amazonaws.com/msaexp-nirspec/extractions/jades-gds-wide-v3/',
        'jades-gds-wide2-v3': 'https://s3.amazonaws.com/msaexp-nirspec/extractions/jades-gds-wide2-v3/',
        'jades-gds-wide3-v3': 'https://s3.amazonaws.com/msaexp-nirspec/extractions/jades-gds-wide3-v3/'
    },

#    '1181': {
#        'jades-gdn-v3': 'https://s3.amazonaws.com/msaexp-nirspec/extractions/jades-gdn-v3/',
#        'jades-gdn09-v3': 'https://s3.amazonaws.com/msaexp-nirspec/extractions/jades-gdn09-v3/',
#        'jades-gdn10-v3': 'https://s3.amazonaws.com/msaexp-nirspec/extractions/jades-gdn10-v3/',
#        'jades-gdn11-v3': 'https://s3.amazonaws.com/msaexp-nirspec/extractions/jades-gdn11-v3/',
#        'jades-gdn2-blue-v3': 'https://s3.amazonaws.com/msaexp-nirspec/extractions/jades-gdn2-blue-v3/',
#        'jades-gdn2-v3': 'https://s3.amazonaws.com/msaexp-nirspec/extractions/jades-gdn2-v3/',
#    },
#
#    '1210': {
#        'gds-deep-v3':'https://s3.amazonaws.com/msaexp-nirspec/extractions/gds-deep-v3/'
#        },
#
#    '1286': {
#        'jades-gds02-v3': 'https://s3.amazonaws.com/msaexp-nirspec/extractions/jades-gds02-v3/',
#        'jades-gds03-v3': 'https://s3.amazonaws.com/msaexp-nirspec/extractions/jades-gds03-v3/',
#        'jades-gds04-v3': 'https://s3.amazonaws.com/msaexp-nirspec/extractions/jades-gds04-v3/',
#        'jades-gds05-v3': 'https://s3.amazonaws.com/msaexp-nirspec/extractions/jades-gds05-v3/',
#        'jades-gds06-v3': 'https://s3.amazonaws.com/msaexp-nirspec/extractions/jades-gds06-v3/',
#        'jades-gds07-v3': 'https://s3.amazonaws.com/msaexp-nirspec/extractions/jades-gds07-v3/',
#        'jades-gds08-v3': 'https://s3.amazonaws.com/msaexp-nirspec/extractions/jades-gds08-v3/',
#        'jades-gds1-v3': 'https://s3.amazonaws.com/msaexp-nirspec/extractions/jades-gds1-v3/',
#    },
#
#    'ultra_deep': {
#        'gds-udeep-v3':'https://s3.amazonaws.com/msaexp-nirspec/extractions/gds-udeep-v3/'
#    }
}

# 3. Analysis Parameters
PEAK_FINDING_HEIGHT = 3.0  # In units of local noise standard deviation
PEAK_PROMINENCE = 1.5      # How much a peak must 'stick out' from its surroundings, in units of local noise.
PEAK_FINDING_DISTANCE = 10 # Minimum separation between peaks in pixels
GAUSSIAN_FIT_WINDOW = 20   # Window size around a peak for fitting, in pixels
WAVELENGTH_MATCH_TOLERANCE = 10 * u.AA # Tolerance for matching fitted peaks to known lines
LINE_INTEGRATION_WIDTH_A = 25.0  # The width in Angstroms to integrate over for each line.
SN_CUTOFF = 5.0                  # The signal-to-noise ratio required to count a line as "detected".
flag_GIDS = []

# --- Emission Line Catalog ---
EMISSION_LINES = {
    # Name: Rest Wavelength (Angstroms)

    # --- Hydrogen: Balmer Series (Visible) ---
    r'H-alpha': 6562.819 * u.AA,
    r'H-beta': 4861.333 * u.AA,
    r'H-gamma': 4340.47 * u.AA,
    r'H-delta': 4101.74 * u.AA,
    r'H-epsilon': 3970.07 * u.AA,

    # --- Hydrogen: Paschen Series (NIR) ---
    r'Pa-alpha': 18750.976 * u.AA,
    r'Pa-beta': 12818.1 * u.AA,
    r'Pa-gamma': 10938.1 * u.AA,
    r'Pa-delta': 10049.0 * u.AA,
    r'Pa-epsilon': 9545.98 * u.AA,
    r'Pa-zeta': 9229.02 * u.AA,
    r'Pa-eta': 9014.91 * u.AA,

    # --- Hydrogen: Brackett Series (NIR) ---
    r'Br-beta': 26251.0 * u.AA,
    r'Br-gamma': 21655.302 * u.AA,
    r'Br-delta': 19445.582 * u.AA,
    r'Br-epsilon': 18174.141 * u.AA,

    # --- Hydrogen: Pfund Series (NIR) ---
    r'Pf-delta': 32960.0 * u.AA,
    r'Pf-epsilon': 30383.731 * u.AA,

    # --- Other notable Hydrogen lines ---
    r'H (15700 Å)': 15700.0 * u.AA,
    r'H (26119 Å)': 26119.351 * u.AA,
    r'H (28722 Å)': 28722.0 * u.AA,

    # --- Helium Lines ---
    r'He I 5875': 5875.0 * u.AA,
    r'He I 10830': 10830.0 * u.AA,
    r'He I 18697': 18697.216 * u.AA,
    r'He II 4686': 4685.68 * u.AA,

    # --- Common Forbidden Lines ("Nebular" Lines) ---
    r'[O I] 6300': 6300 * u.AA,
    r'[O II] 3727': 3727.3 * u.AA,    # Doublet avg.
    r'[O III] 4959': 4958.91 * u.AA,
    r'[O III] 5007': 5006.84 * u.AA,
    r'[N II] 6583': 6583.4 * u.AA,    # Often blended with H-alpha
    r'[S II] 6716': 6716.4 * u.AA,
    r'[S II] 6731': 6730.8 * u.AA,

    # --- High-Ionization / AGN Lines ---
    # These lines indicate a very hard radiation field, often from an AGN.
    # Some are UV lines, only visible in NIR spectra for high-redshift objects.
    r'[C IV] 1549': 1549.0 * u.AA,           # UV, z > ~4 for NIRSpec
    r'[C III] 1909': 1908.7 * u.AA,         # UV, z > ~3 for NIRSpec
    r'[Mg II] 2798': 2798.0 * u.AA,          # UV, z > ~2 for NIRSpec
    r'[Ne V] 3346': 3345.8 * u.AA,
    r'[Ne V] 3426': 3425.9 * u.AA,
    r'[Ne III] 3869': 3868.8 * u.AA,
    r'[Ar IV] 4740': 4740.2 * u.AA,
    r'[Fe VII] 6087': 6087.0 * u.AA,
}

# Define a set of line names that indicate high-ionization or AGN activity
FLAG_LINES = {
    r'[C IV] 1549',
    r'[C III] 1909',
    r'[Mg II] 2798',
    r'[Ne V] 3346',
    r'[Ne V] 3426',
    r'[Ne III] 3869',
    r'He II 4686',
    r'[Ar IV] 4740',
    r'[Fe VII] 6087',
}

# %%
# --- Logger Setup ---
# This block replaces the need for a global 'debug' variable.

# 1. Create a filename for the detailed log file
# Example: 'log_2025-06-08_19-38.log'
log_filename = f"log_{datetime.now().strftime('%Y-%m-%d_%H-%M')}.log"
# In Colab/Drive, you might want to specify the full path:
log_filepath = "/content/drive/MyDrive/Bren_code/My_work/JADES_Analysis/logs/" + log_filename

# 2. Get the root logger
logger = logging.getLogger()
logger.setLevel(logging.DEBUG) # Set the lowest level to capture ALL messages

# 3. Create a handler to write to the CONSOLE (for high-level info)
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO) # Only shows INFO, WARNING, ERROR, CRITICAL
console_formatter = logging.Formatter('%(message)s') # Keep console output clean
console_handler.setFormatter(console_formatter)

# 4. Create a handler to write to the FILE (for all the details)
file_handler = logging.FileHandler(log_filepath)
file_handler.setLevel(logging.DEBUG) # Captures EVERY level, including DEBUG
file_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
file_handler.setFormatter(file_formatter)

# 5. Add the handlers to the logger
# Important: Clear existing handlers to prevent duplicate logs in notebooks
if (logger.hasHandlers()):
    logger.handlers.clear()
logger.addHandler(console_handler)
logger.addHandler(file_handler)

# --- End Logger Setup ---
# Now, you can use logger.info(), logger.debug(), etc. throughout your code.
logger.info(f"Logger initialized. Detailed debug output will be saved to: {log_filepath}")
# Out:
# Logger initialized. Detailed debug output will be saved to: /content/drive/MyDrive/Bren_code/My_work/JADES_Analysis/logs/log_2025-09-09_17-03.log

# %%
# === Helper Functions (Final Stable Version) ===

def download_jades_data(projects, csv_parent_path, base_save_path):
    """
    Downloads JADES FITS files, using a separate CSV file for each
    individual pointing.
    """
    # This function is working well and does not need changes.
    logger.info("====================" * 6)
    logger.info("--- Beginning JADES Data Download (Pointing-Specific CSVs) ---")
    count = 0
    for program_id, pointings_dict in projects.items():
        logger.info("-------------------------------------------------")
        logger.info(f"Processing Program ID: {program_id}")
        program_save_path = os.path.join(base_save_path, program_id)
        os.makedirs(program_save_path, exist_ok=True)
        for pointing_name, data_url in pointings_dict.items():
            logger.info(f"  --> Processing pointing: {pointing_name}")
            csv_filename = f"{program_id}-{pointing_name}.csv"
            target_list_path = os.path.join(csv_parent_path, csv_filename)
            try:
                target_list = pd.read_csv(target_list_path)
                logger.info(f"    Loaded {len(target_list)} targets from '{csv_filename}'.")
            except FileNotFoundError:
                logger.warning(f"    Target list '{csv_filename}' not found. Skipping this pointing.")
                continue
            for i, row in target_list.iterrows():
                target_file = row['file']
                file_path = os.path.join(program_save_path, target_file)
                if os.path.exists(file_path):
                    logger.debug(f"    Skipping '{target_file}', already downloaded.")
                    continue
                file_url = data_url + target_file
                logger.info(f"    Downloading: {target_file}")
                try:
                    r = requests.get(file_url, allow_redirects=True, timeout=120)
                    r.raise_for_status()
                    with open(file_path, 'wb') as f:
                        f.write(r.content)
                        count += 1
                    with fits.open(file_path) as hdul:
                        logger.debug(f"      ✓ FITS verification successful.")
                except Exception as e:
                    logger.error(f"      ✗ An error occurred for '{target_file}': {e}")
    logger.info("====================" * 6)
    logger.info("!!!! JADES DOWNLOAD COMPLETE !!!!")
    logger.info(f"Total files downloaded: {count}")
    logger.info("====================" * 6)


def combine_gratings_specutils(base_data_folder):
    """
    Recursively finds all .spec.fits files, groups by GID, and combines into Spectrum1D objects.
    """
    # This function is working well and does not need changes.
    logger.info("====================" * 6)
    logger.info("--- Beginning grating combination for JADES ---")
    all_fits_files = [os.path.join(root, file) for root, dirs, files in os.walk(base_data_folder) for file in files if file.endswith('.spec.fits')]
    logger.info(f"Found {len(all_fits_files)} total '.spec.fits' files across all subdirectories.")
    grouped_spectra = defaultdict(list)
    for fits_path in all_fits_files:
        filename = os.path.basename(fits_path)
        try:
            galaxy_id = filename.split('_')[-1].replace('.spec.fits', '')
            grouped_spectra[galaxy_id].append(fits_path)
        except IndexError:
            logger.warning(f"Could not parse galaxy ID from {filename}. Skipping.")
            continue
    logger.info(f"Total unique galaxy IDs found: {len(grouped_spectra)}")
    combined_spectra = {}
    for galaxy_id, file_paths in sorted(grouped_spectra.items()):
        all_wave, all_flux, all_err = [], [], []
        source_filenames = [os.path.basename(p) for p in file_paths]
        for f_path in file_paths:
            try:
                with fits.open(f_path) as hdul:
                    data = hdul[1].data
                    all_wave.append(data['wave'])
                    all_flux.append(data['flux'])
                    all_err.append(data['err'])
            except Exception as e:
                logger.error(f"GID {galaxy_id}: Failed to process file '{os.path.basename(f_path)}'. Reason: {e}")
                continue
        if not all_wave: continue
        wave, flux, err = np.concatenate(all_wave), np.concatenate(all_flux), np.concatenate(all_err)
        sort_idx = np.argsort(wave)
        spectrum_object = Spectrum1D(
            flux=flux[sort_idx] * u.uJy,
            spectral_axis=wave[sort_idx] * u.um,
            uncertainty=StdDevUncertainty(err[sort_idx] * u.uJy))
        combined_spectra[galaxy_id] = {'spectrum': spectrum_object, 'source_files': source_filenames}
    logger.info("--- Combination Complete ---")
    logger.info(f"Successfully processed and stored data for {len(combined_spectra)} galaxies.")
    return combined_spectra


def create_specialized_template(template_type):
    """
    Creates a specialized emission line template (UV, Optical, or IR).
    """
    # This function is working well and does not need changes.
    lines = []
    if template_type == 'optical':
        wave_range = np.arange(3700, 6800, 1.0)
        lines = [(3727.0, 2.0), (4861.3, 1.0), (4958.9, 1.5), (5006.8, 4.5), (6548.1, 0.5), (6562.8, 3.5), (6583.4, 1.5), (6716.4, 0.6), (6730.8, 0.5)]
    elif template_type == 'ir':
        wave_range = np.arange(8500, 19000, 10.0)
        lines = [(10049.0, 0.8), (10938.1, 1.0), (12818.1, 1.5), (18750.9, 2.0), (10830.0, 1.2)]
    elif template_type == 'uv':
        wave_range = np.arange(1200, 3000, 1.0)
        lines = [(1215.7, 5.0), (1549.0, 2.0), (1908.7, 2.5), (2798.0, 1.5)]
    flux_axis = np.zeros(len(wave_range))
    for wave, strength in lines:
        flux_axis += Gaussian1D.evaluate(wave_range, amplitude=strength, mean=wave, stddev=2.0)
    return wave_range, flux_axis


def correct_redshift_xcorr(spectrum, initial_z, galaxy_id):
    """
    Uses a manual numpy cross-correlation to find the redshift correction.
    """
    # This function is working well and does not need changes.
    best_z = initial_z
    max_corr_peak = -np.inf
    best_template_type = 'none'
    for template_type in ['optical', 'ir', 'uv']:
        try:
            template_wave, template_flux = create_specialized_template(template_type)
            rest_wave_val = (spectrum.spectral_axis / (1 + initial_z)).to_value(u.AA)
            rest_flux_val = spectrum.flux.value
            resampled_flux = np.interp(template_wave, rest_wave_val, rest_flux_val)
            if np.all(resampled_flux == 0.0): continue
            correlation = np.correlate(resampled_flux, template_flux, mode='same')
            current_peak = np.max(correlation)
            if current_peak > max_corr_peak:
                max_corr_peak = current_peak
                best_template_type = template_type
                pixel_lags = np.arange(len(correlation)) - len(correlation) // 2
                dw_per_pixel = np.median(np.diff(template_wave))
                center_wave = np.median(template_wave)
                dv_per_pixel = (const.c.to('km/s').value * dw_per_pixel / center_wave)
                velocity_lags_kms = pixel_lags * dv_per_pixel
                velocity_offset = velocity_lags_kms[np.argmax(correlation)] * u.km / u.s
                delta_z = velocity_offset / const.c
                best_z = (initial_z + delta_z * (1 + initial_z)).value
        except Exception as e:
            logger.debug(f"  Template '{template_type}' failed for GID {galaxy_id}: {e}")
            continue
    if best_template_type != 'none':
        logger.info(f"  Redshift Correction (Best Match: '{best_template_type}' template): Initial z={initial_z:.5f} -> Corrected z={best_z:.5f}")
        return best_z
    else:
        logger.warning(f"  Cross-correlation failed for all templates. Using initial redshift.")
        return initial_z


def fit_continuum_stable(spectrum):
    """
    Fits and subtracts the continuum, robustly handling non-finite values.
    """
    # This function is working well and does not need changes.
    from astropy.modeling.models import Chebyshev1D
    from astropy.modeling.fitting import LevMarLSQFitter, FittingWithOutlierRemoval
    flux_clean, uncert_clean = spectrum.flux.value.copy(), spectrum.uncertainty.array.copy()
    bad_mask = ~np.isfinite(flux_clean) | ~np.isfinite(uncert_clean)
    if np.any(bad_mask):
        good_indices = np.where(~bad_mask)[0]
        if good_indices.size < 2: raise ValueError("Not enough finite data points for interpolation.")
        bad_indices = np.where(bad_mask)[0]
        flux_clean[bad_mask] = np.interp(bad_indices, good_indices, flux_clean[good_indices])
        uncert_clean[bad_mask] = np.interp(bad_indices, good_indices, uncert_clean[good_indices])
    fitter = LevMarLSQFitter()
    robust_fitter = FittingWithOutlierRemoval(fitter, sigma_clip, niter=3, sigma=3.0)
    continuum_model_init = Chebyshev1D(degree=5)
    fitted_model, _ = robust_fitter(continuum_model_init, spectrum.spectral_axis.value, flux_clean)
    continuum_flux = fitted_model(spectrum.spectral_axis.value) * spectrum.flux.unit
    subtracted_spectrum = spectrum - continuum_flux
    return subtracted_spectrum, continuum_flux


def gaussian(x, amplitude, mean, stddev):
    """A standard Gaussian function for fitting."""
    return amplitude * np.exp(-((x - mean)**2) / (2 * stddev**2))


def find_and_fit_lines(spectrum_sub):
    """
    NEW "Hunt-then-Identify" line fitting function. This is a major upgrade.
    1. Finds all significant peaks in the spectrum.
    2. Fits a Gaussian to each peak to get precise parameters and errors.
    3. Matches the fitted peak to the closest known emission line.
    """
    line_fits = {}

    # --- 1. Hunt for Peaks ---
    # Use the smoothed uncertainty as the basis for our detection threshold
    local_noise = savgol_filter(spectrum_sub.uncertainty.array, 51, 3)
    peaks, properties = find_peaks(
        spectrum_sub.flux.value,
        height=local_noise * PEAK_FINDING_HEIGHT,
        prominence=local_noise * PEAK_PROMINENCE,
        distance=PEAK_FINDING_DISTANCE
    )

    if peaks.size == 0:
        return {} # Return empty if no peaks are found

    logger.info(f"  Found {len(peaks)} significant emission line candidates. Now fitting...")

    # --- 2. Fit and Identify Each Peak ---
    for i, peak_idx in enumerate(peaks):
        peak_wave = spectrum_sub.spectral_axis[peak_idx].to_value(u.AA)

        # Define a small window around the peak for fitting
        min_wave = peak_wave - GAUSSIAN_FIT_WINDOW
        max_wave = peak_wave + GAUSSIAN_FIT_WINDOW

        mask = (spectrum_sub.spectral_axis.to_value(u.AA) > min_wave) & (spectrum_sub.spectral_axis.to_value(u.AA) < max_wave)

        wave_subset = spectrum_sub.spectral_axis.value[mask]
        flux_subset = spectrum_sub.flux.value[mask]
        err_subset = spectrum_sub.uncertainty.array[mask]

        if len(wave_subset) < 4: continue # Not enough points to fit

        try:
            # Use curve_fit to get both params (popt) and covariance (pcov)
            p0 = [properties['peak_heights'][i], peak_wave, 2.0] # Initial guess: amp, mean, stddev
            popt, pcov = curve_fit(gaussian, wave_subset, flux_subset, p0=p0, sigma=err_subset, absolute_sigma=True)

            # --- 3. Extract parameters and errors from the fit ---
            amplitude, center_A, stddev_A = popt
            # Errors are the sqrt of the diagonal of the covariance matrix
            amp_err, center_err, stddev_err = np.sqrt(np.diag(pcov))

            integrated_flux = amplitude * stddev_A * np.sqrt(2 * np.pi)
            # Propagate error for the integrated flux
            flux_err = integrated_flux * np.sqrt((amp_err/amplitude)**2 + (stddev_err/stddev_A)**2)

            snr = integrated_flux / flux_err if flux_err > 0 else 0.0

            if snr >= SN_CUTOFF:
                # --- 4. Match the fitted line to the closest line in our catalog ---
                all_line_waves = np.array([line.value for line in EMISSION_LINES.values()])
                all_line_names = list(EMISSION_LINES.keys())

                wave_diff = np.abs(all_line_waves - center_A)
                closest_idx = np.argmin(wave_diff)

                if wave_diff[closest_idx] < WAVELENGTH_MATCH_TOLERANCE.value:
                    line_name = all_line_names[closest_idx]
                    # Avoid overwriting a stronger detection of the same line
                    if line_name not in line_fits or snr > line_fits[line_name]['snr']:
                        line_fits[line_name] = {
                            'flux': integrated_flux, 'flux_err': flux_err,
                            'snr': snr, 'fit_center_A': center_A
                        }
                        logger.info(f"    ✓ {line_name}: DETECTED with S/N = {snr:.2f}")

        except Exception as e:
            logger.debug(f"    - Fit failed for peak near {peak_wave:.1f} Å: {e}")
            continue

    return line_fits


def run_analysis_on_galaxy(spectrum_object, initial_z, galaxy_id, make_plots=True):
    """
    Top-level analysis function for a single galaxy.
    """
    z_corr = correct_redshift_xcorr(spectrum_object, initial_z, galaxy_id)

    wave_obs, flux_obs_fnu, err_obs_fnu = spectrum_object.spectral_axis, spectrum_object.flux, spectrum_object.uncertainty.quantity
    wave_rest, flux_rest_fnu, err_rest_fnu = wave_obs/(1+z_corr), flux_obs_fnu*(1+z_corr), err_obs_fnu*(1+z_corr)
    wave_rest_aa = wave_rest.to(u.AA)
    fnu_to_flambda_conv = (const.c / wave_rest_aa**2).to(u.erg/u.s/u.cm**2/u.AA/u.uJy)
    flux_flambda, err_flambda = flux_rest_fnu*fnu_to_flambda_conv, err_rest_fnu*fnu_to_flambda_conv
    spec_flam = Spectrum1D(
        flux=flux_flambda,
        spectral_axis=wave_rest_aa,
        uncertainty=StdDevUncertainty(err_flambda))

    try:
        spec_sub, continuum_flux = fit_continuum_stable(spec_flam)
        if make_plots:
            create_continuum_diagnostic_plot(galaxy_id, spec_flam, continuum_flux, spec_sub, PLOT_PATH)
    except Exception as e:
        logger.error(f"  Continuum fitting failed for GID {galaxy_id}: {e}. Skipping galaxy.")
        return None

    # Call the new "hunt-then-identify" line fitting function
    line_fits = find_and_fit_lines(spec_sub)

    if make_plots and line_fits:
        plot_and_save_results(galaxy_id, z_corr, spec_flam, line_fits, PLOT_PATH)

    final_results = {'galaxy_id': galaxy_id, 'redshift_initial': initial_z, 'redshift_corrected': z_corr}
    for line_name in EMISSION_LINES.keys():
        safe_name = line_name.replace(' ', '').replace('[','').replace(']','').replace(r'\\','').replace(r'$','').replace('-','').replace('Å','')
        if line_name in line_fits:
            final_results[f'{safe_name}_flux'] = line_fits[line_name]['flux']
            final_results[f'{safe_name}_flux_err'] = line_fits[line_name]['flux_err']
            final_results[f'{safe_name}_snr'] = line_fits[line_name]['snr']
            final_results[f'{safe_name}_fit_center_A'] = line_fits[line_name]['fit_center_A']
        else:
            for suffix in ['_flux', '_flux_err', '_snr', '_fit_center_A']:
                final_results[f'{safe_name}{suffix}'] = np.nan

    found_flag_lines = FLAG_LINES.intersection(line_fits.keys())
    if found_flag_lines:
        logger.warning(f"  >>> AGN/HIGH-IONIZATION SIGNATURE DETECTED! Flagged lines: {sorted(list(found_flag_lines))}")
    final_results['agn_flag'] = len(found_flag_lines) > 0

    return final_results


def create_continuum_diagnostic_plot(galaxy_id, spectrum, continuum, spec_sub, save_dir):
    """
    Creates and saves a plot to diagnose the continuum subtraction process.
    """
    # This function is working well and does not need changes.
    from astropy.visualization import quantity_support
    quantity_support()
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(18, 10), sharex=True,
                                   gridspec_kw={'height_ratios': [2, 1]})
    ax1.plot(spectrum.spectral_axis, spectrum.flux, color='grey', lw=1, label='Original Spectrum')
    ax1.plot(spectrum.spectral_axis, continuum, color='red', linestyle='--', lw=2, label='Continuum Model')
    ax1.set_title(f'Continuum Subtraction Diagnostic for Galaxy {galaxy_id}', fontsize=16)
    ax1.legend()
    ax2.plot(spec_sub.spectral_axis, spec_sub.flux, color='black', lw=1, label='Continuum-Subtracted Flux')
    ax2.fill_between(spec_sub.spectral_axis, -spec_sub.uncertainty.quantity, spec_sub.uncertainty.quantity,
                     color='cyan', alpha=0.5, label='1-sigma Noise')
    ax2.axhline(0, color='red', linestyle=':', lw=1)
    ax2.set_ylabel('Subtracted Flux')
    ax2.legend()
    plot_std = np.nanmedian(spec_sub.uncertainty.array) * 10
    if np.isfinite(plot_std) and plot_std > 0:
        ax2.set_ylim(-plot_std, plot_std)
    plt.tight_layout()
    plt.subplots_adjust(hspace=0.05)
    plot_filename = os.path.join(save_dir, f'diagnostic_continuum_{galaxy_id}.png')
    plt.savefig(plot_filename, dpi=150)
    plt.close(fig)
    logger.info(f"  → Continuum diagnostic plot saved to {os.path.basename(plot_filename)}")


def plot_and_save_results(galaxy_id, redshift, spectrum, line_fits, save_dir):
    """
    Generates and saves a final plot showing the spectrum and detected lines.
    """
    # This function is working well and does not need changes.
    from astropy.visualization import quantity_support
    quantity_support()

    max_flux_value = np.max(spectrum.flux[np.isfinite(spectrum.flux.value)])
    if max_flux_value == 0: # Handle edge case of all-zero flux
        exponent = 0
    else:
        exponent = int(np.floor(np.log10(abs(max_flux_value.value))))

    scaling_factor = 10**exponent
    scale_flux = spectrum.flux / scaling_factor
    scale_err = spectrum.uncertainty.quantity / scaling_factor
    spectrum = Spectrum1D(
        flux=scale_flux,
        spectral_axis=spectrum.spectral_axis,
        uncertainty=StdDevUncertainty(scale_err))

    fig, ax = plt.subplots(figsize=(18, 7))
    ax.plot(spectrum.spectral_axis, spectrum.flux, label='Spectrum (Rest-frame)', color='black', lw=0.8)

    for line_name, fit_info in line_fits.items():
        center_wave = fit_info['fit_center_A'] * u.AA
        ax.axvline(center_wave.value, color='red', linestyle='--', alpha=0.7,
                    label=f"{line_name} (S/N: {fit_info['snr']:.1f})")

    ax.set_xlabel(r'$\lambda$ [$\AA$]', fontsize=14)
    y_label_string = rf'$F_{{\lambda}}$ [$10^{{{exponent}}}$ erg s$^{{-1}}$ cm$^{{-2}}$ $\AA^{{-1}}$]'

    ax.set_ylabel(y_label_string, fontsize=14)
    ax.set_title(f'Spectrum and Detected Lines for Galaxy {galaxy_id} (z={redshift:.4f})', fontsize=14)

    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys(), loc='upper right')

    ax.set_xlim(np.nanmin(spectrum.spectral_axis.value), np.nanmax(spectrum.spectral_axis.value))
    med_flux, std_flux = np.nanmedian(spectrum.flux.value), np.nanstd(spectrum.flux.value)
    if np.isfinite(med_flux) and np.isfinite(std_flux):
        ax.set_ylim(med_flux - 2 * std_flux, med_flux + 7 * std_flux)

    plt.tight_layout()
    plot_filename = os.path.join(save_dir, f'spectrum_{galaxy_id}.png')
    plt.savefig(plot_filename, dpi=150)
    plt.close(fig)
    logger.info(f"  → Final results plot saved to {os.path.basename(plot_filename)}")

# %%
def main():
    """
    Main function to run the entire analysis pipeline for JADES data.
    """
    logger.info("====================" * 6)
    logger.info("--- Starting JADES Main Analysis Pipeline ---")
    os.makedirs(PLOT_PATH, exist_ok=True)

    try:
        df_redshifts = pd.read_csv(TARGET_LIST_PATH)
        df_redshifts['galaxy_id'] = df_redshifts['galaxy_id'].astype(int)
        logger.info(f"Master redshift catalog loaded with {len(df_redshifts)} entries.")
    except Exception as e:
        logger.critical(f"Failed to load or parse target list '{TARGET_LIST_PATH}': {e}")
        return

    processed_spectra = combine_gratings_specutils(SAVE_PATH)
    if not processed_spectra:
        logger.critical("No spectra were processed. Halting.")
        return

    all_galaxy_results = []
    for galaxy_id_str, spec_info in processed_spectra.items():
        logger.info("-------------------------------------------------")

        try:
            galaxy_id = int(galaxy_id_str)
        except ValueError:
            logger.warning(f"Could not convert GID '{galaxy_id_str}' to integer. Skipping.")
            continue

        logger.info(f"Processing Galaxy ID: {galaxy_id}")

        z_rows = df_redshifts[df_redshifts['galaxy_id'] == galaxy_id]

        if z_rows.empty:
            logger.warning(f"  Could not find redshift for GID {galaxy_id} in the master catalog. Skipping.")
            continue

        redshift = z_rows['z'].iloc[0]

        galaxy_data_row = run_analysis_on_galaxy(spec_info['spectrum'], redshift, galaxy_id)
        if galaxy_data_row:
            all_galaxy_results.append(galaxy_data_row)

    if all_galaxy_results:
        logger.info("====================" * 6)
        logger.info("--- Saving Final Flux Catalog ---")
        results_df = pd.DataFrame(all_galaxy_results)
        cols = ['galaxy_id', 'redshift_initial', 'redshift_corrected', 'agn_flag'] + sorted(
            [c for c in results_df.columns if c not in ['galaxy_id', 'redshift_initial', 'redshift_corrected', 'agn_flag']])
        results_df = results_df[cols]
        try:
            results_df.to_csv(OUTPUT_CATALOG_PATH, index=False, float_format='%.5e')
            logger.info(f"SUCCESS: Final catalog saved to: {OUTPUT_CATALOG_PATH}")
        except Exception as e:
            logger.critical(f"Failed to save the final catalog. Reason: {e}")
    else:
        logger.warning("No galaxies were processed successfully. Final catalog was not created.")

    logger.info("====================" * 6)
    logger.info("!!!! ANALYSIS COMPLETE !!!!")

# %%
# === Driver ===
if __name__ == "__main__":
    start = time.time()
    main()
    logger.info(f"Total time taken: {time.time() - start:.2f} seconds")
# Out:
# ========================================================================================================================
# --- Starting JADES Main Analysis Pipeline ---
# Master redshift catalog loaded with 4424 entries.
# ========================================================================================================================
# --- Beginning grating combination for JADES ---
# Found 4579 total '.spec.fits' files across all subdirectories.
# Total unique galaxy IDs found: 1276
# --- Combination Complete ---
# Successfully processed and stored data for 1276 galaxies.
# -------------------------------------------------
# Processing Galaxy ID: -1
#   Could not find redshift for GID -1 in the master catalog. Skipping.
# -------------------------------------------------
# Processing Galaxy ID: -2
#   Could not find redshift for GID -2 in the master catalog. Skipping.
# -------------------------------------------------
# Processing Galaxy ID: -3
#   Could not find redshift for GID -3 in the master catalog. Skipping.
# -------------------------------------------------
# Processing Galaxy ID: 10004141
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10004141.png
#   Found 58 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10004765
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10004765.png
#   Found 64 significant emission line candidates. Now fitting...
#     ✓ [O III] 5007: DETECTED with S/N = 14.52
#     ✓ H-alpha: DETECTED with S/N = 17.47
#   → Final results plot saved to spectrum_10004765.png
# -------------------------------------------------
# Processing Galaxy ID: 10007444
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10007444.png
#   Found 50 significant emission line candidates. Now fitting...
#     ✓ [S II] 6716: DETECTED with S/N = 6.68
#     ✓ Pa-beta: DETECTED with S/N = 9.67
#   → Final results plot saved to spectrum_10007444.png
# -------------------------------------------------
# Processing Galaxy ID: 10008728
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10008728.png
#   Found 50 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10010247
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10010247.png
#   Found 81 significant emission line candidates. Now fitting...
#     ✓ Pa-gamma: DETECTED with S/N = 24.80
#   → Final results plot saved to spectrum_10010247.png
# -------------------------------------------------
# Processing Galaxy ID: 10010433
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10010433.png
#   Found 76 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10010487
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10010487.png
#   Found 59 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10010937
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10010937.png
#   Found 55 significant emission line candidates. Now fitting...
#     ✓ [O II] 3727: DETECTED with S/N = 5.08
#   → Final results plot saved to spectrum_10010937.png
# -------------------------------------------------
# Processing Galaxy ID: 10011015
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10011015.png
#   Found 64 significant emission line candidates. Now fitting...
#     ✓ [O III] 5007: DETECTED with S/N = 21.28
#     ✓ H-alpha: DETECTED with S/N = 21.86
#     ✓ He I 10830: DETECTED with S/N = 5.70
#   → Final results plot saved to spectrum_10011015.png
# -------------------------------------------------
# Processing Galaxy ID: 10011037
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10011037.png
#   Found 62 significant emission line candidates. Now fitting...
#     ✓ H-alpha: DETECTED with S/N = 17.43
#   → Final results plot saved to spectrum_10011037.png
# -------------------------------------------------
# Processing Galaxy ID: 10011069
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10011069.png
#   Found 58 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10011141
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10011141.png
#   Found 72 significant emission line candidates. Now fitting...
#     ✓ H-beta: DETECTED with S/N = 12.14
#     ✓ He I 10830: DETECTED with S/N = 5.25
#     ✓ Pa-alpha: DETECTED with S/N = 8.50
#   → Final results plot saved to spectrum_10011141.png
# -------------------------------------------------
# Processing Galaxy ID: 10012070
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10012070.png
#   Found 55 significant emission line candidates. Now fitting...
#     ✓ He I 5875: DETECTED with S/N = 5.24
#     ✓ H-alpha: DETECTED with S/N = 73.49
#     ✓ [S II] 6716: DETECTED with S/N = 6.77
#     ✓ He I 10830: DETECTED with S/N = 23.17
#     ✓ Pa-gamma: DETECTED with S/N = 8.17
#     ✓ Pa-beta: DETECTED with S/N = 6.57
#   → Final results plot saved to spectrum_10012070.png
# -------------------------------------------------
# Processing Galaxy ID: 10012102
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10012102.png
#   Found 70 significant emission line candidates. Now fitting...
#     ✓ H-gamma: DETECTED with S/N = 5.82
#     ✓ H-beta: DETECTED with S/N = 15.19
#     ✓ [O III] 4959: DETECTED with S/N = 21.38
#     ✓ [O III] 5007: DETECTED with S/N = 52.78
#     ✓ H-alpha: DETECTED with S/N = 22.86
#   → Final results plot saved to spectrum_10012102.png
# -------------------------------------------------
# Processing Galaxy ID: 10013169
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10013169.png
#   Found 68 significant emission line candidates. Now fitting...
#     ✓ [O II] 3727: DETECTED with S/N = 17.79
#     ✓ [Ne III] 3869: DETECTED with S/N = 12.28
#     ✓ H-epsilon: DETECTED with S/N = 6.62
#     ✓ H-delta: DETECTED with S/N = 9.35
#     ✓ H-beta: DETECTED with S/N = 33.22
#     ✓ [O III] 4959: DETECTED with S/N = 58.45
#     ✓ [O III] 5007: DETECTED with S/N = 93.62
#     ✓ He I 5875: DETECTED with S/N = 5.86
#     ✓ H-alpha: DETECTED with S/N = 66.10
#     ✓ [S II] 6716: DETECTED with S/N = 7.70
#   → Final results plot saved to spectrum_10013169.png
#   >>> AGN/HIGH-IONIZATION SIGNATURE DETECTED! Flagged lines: ['[Ne III] 3869']
# -------------------------------------------------
# Processing Galaxy ID: 10013268
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10013268.png
#   Found 118 significant emission line candidates. Now fitting...
#     ✓ H-beta: DETECTED with S/N = 7.51
#     ✓ [O III] 4959: DETECTED with S/N = 13.65
#     ✓ [O III] 5007: DETECTED with S/N = 28.32
#     ✓ H-alpha: DETECTED with S/N = 28.64
#   → Final results plot saved to spectrum_10013268.png
# -------------------------------------------------
# Processing Galaxy ID: 10013314
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10013314.png
#   Found 71 significant emission line candidates. Now fitting...
#     ✓ [O III] 4959: DETECTED with S/N = 11.29
#     ✓ [O III] 5007: DETECTED with S/N = 17.54
#     ✓ H-alpha: DETECTED with S/N = 16.02
#   → Final results plot saved to spectrum_10013314.png
# -------------------------------------------------
# Processing Galaxy ID: 10013487
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10013487.png
#   Found 78 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10013523
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10013523.png
#   Found 69 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10013534
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10013534.png
#   Found 54 significant emission line candidates. Now fitting...
#     ✓ [O II] 3727: DETECTED with S/N = 5.21
#     ✓ H-beta: DETECTED with S/N = 10.43
#     ✓ H-alpha: DETECTED with S/N = 17.43
#   → Final results plot saved to spectrum_10013534.png
# -------------------------------------------------
# Processing Galaxy ID: 10013834
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10013834.png
#   Found 67 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10034850
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10034850.png
#   Found 62 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 100476
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_100476.png
#   Found 61 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10105320
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10105320.png
#   Found 55 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10105773
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10105773.png
#   Found 64 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10106071
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10106071.png
#   Found 58 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10106146
#   Could not find redshift for GID 10106146 in the master catalog. Skipping.
# -------------------------------------------------
# Processing Galaxy ID: 10106221
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10106221.png
#   Found 72 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10106225
#   Could not find redshift for GID 10106225 in the master catalog. Skipping.
# -------------------------------------------------
# Processing Galaxy ID: 10106930
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10106930.png
#   Found 57 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10106939
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10106939.png
#   Found 94 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10107244
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10107244.png
#   Found 83 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10110822
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10110822.png
#   Found 72 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 103176
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_103176.png
#   Found 51 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 103483
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_103483.png
#   Found 59 significant emission line candidates. Now fitting...
#     ✓ [O III] 4959: DETECTED with S/N = 8.57
#     ✓ [O III] 5007: DETECTED with S/N = 17.78
#     ✓ H-alpha: DETECTED with S/N = 12.36
#   → Final results plot saved to spectrum_103483.png
# -------------------------------------------------
# Processing Galaxy ID: 10459
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10459.png
#   Found 51 significant emission line candidates. Now fitting...
#     ✓ [O II] 3727: DETECTED with S/N = 9.19
#     ✓ H-alpha: DETECTED with S/N = 29.03
#     ✓ [S II] 6716: DETECTED with S/N = 8.20
#     ✓ He I 10830: DETECTED with S/N = 11.04
#     ✓ Pa-beta: DETECTED with S/N = 11.33
#   → Final results plot saved to spectrum_10459.png
# -------------------------------------------------
# Processing Galaxy ID: 1047
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_1047.png
#   Found 63 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 104732
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_104732.png
#   Found 61 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 104738
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_104738.png
#   Found 63 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 104954
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_104954.png
#   Found 61 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 105068
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_105068.png
#   Found 49 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 105273
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_105273.png
#   Found 62 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 105373
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_105373.png
#   Found 62 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 105546
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_105546.png
#   Found 67 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 105581
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_105581.png
#   Found 68 significant emission line candidates. Now fitting...
#     ✓ H-beta: DETECTED with S/N = 13.90
#     ✓ [O III] 4959: DETECTED with S/N = 19.66
#     ✓ [O III] 5007: DETECTED with S/N = 31.68
#     ✓ H-alpha: DETECTED with S/N = 37.16
#   → Final results plot saved to spectrum_105581.png
# -------------------------------------------------
# Processing Galaxy ID: 105587
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_105587.png
#   Found 64 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 105683
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_105683.png
#   Found 66 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 105727
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_105727.png
#   Found 66 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 105758
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_105758.png
#   Found 77 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 105813
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_105813.png
#   Found 79 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 105840
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_105840.png
#   Found 97 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 105924
#   Redshift Correction (Best Match: 'optical' template): Initial z=2.22000 -> Corrected z=2.23411
#   → Continuum diagnostic plot saved to diagnostic_continuum_105924.png
#   Found 2 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 106037
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_106037.png
#   Found 54 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 106062
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_106062.png
#   Found 64 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 106076
#   Redshift Correction (Best Match: 'optical' template): Initial z=2.93920 -> Corrected z=2.44844
#   → Continuum diagnostic plot saved to diagnostic_continuum_106076.png
#   Found 7 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 106126
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_106126.png
#   Found 53 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 106198
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_106198.png
#   Found 46 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 106206
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_106206.png
#   Found 107 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 106388
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_106388.png
#   Found 60 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 106696
#   Redshift Correction (Best Match: 'optical' template): Initial z=2.88910 -> Corrected z=2.53201
#   → Continuum diagnostic plot saved to diagnostic_continuum_106696.png
#   Found 4 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 106704
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_106704.png
#   Found 69 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 106719
#   Redshift Correction (Best Match: 'optical' template): Initial z=2.91290 -> Corrected z=3.56213
#   → Continuum diagnostic plot saved to diagnostic_continuum_106719.png
#   Found 6 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 106767
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_106767.png
#   Found 51 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 106780
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_106780.png
#   Found 84 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 106795
#   Could not find redshift for GID 106795 in the master catalog. Skipping.
# -------------------------------------------------
# Processing Galaxy ID: 106914
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_106914.png
#   Found 55 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 107092
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_107092.png
#   Found 61 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 107102
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_107102.png
#   Found 62 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10715
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10715.png
#   Found 66 significant emission line candidates. Now fitting...
#     ✓ [O II] 3727: DETECTED with S/N = 11.67
#     ✓ H-alpha: DETECTED with S/N = 39.96
#   → Final results plot saved to spectrum_10715.png
# -------------------------------------------------
# Processing Galaxy ID: 107389
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_107389.png
#   Found 57 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 107485
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_107485.png
#   Found 59 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 107500
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_107500.png
#   Found 53 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 107512
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_107512.png
#   Found 50 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 107523
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_107523.png
#   Found 80 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 107593
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_107593.png
#   Found 46 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 107700
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_107700.png
#   Found 78 significant emission line candidates. Now fitting...
#     ✓ H-alpha: DETECTED with S/N = 22.22
#     ✓ [N II] 6583: DETECTED with S/N = 31.34
#     ✓ [S II] 6716: DETECTED with S/N = 8.27
#     ✓ He I 10830: DETECTED with S/N = 12.01
#     ✓ Pa-beta: DETECTED with S/N = 7.86
#   → Final results plot saved to spectrum_107700.png
# -------------------------------------------------
# Processing Galaxy ID: 107774
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_107774.png
#   Found 63 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10825
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10825.png
#   Found 70 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 108708
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_108708.png
#   Found 77 significant emission line candidates. Now fitting...
#     ✓ H-alpha: DETECTED with S/N = 5.55
#   → Final results plot saved to spectrum_108708.png
# -------------------------------------------------
# Processing Galaxy ID: 10894
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10894.png
#   Found 70 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 109026
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_109026.png
#   Found 75 significant emission line candidates. Now fitting...
#     ✓ H-beta: DETECTED with S/N = 5.68
#     ✓ [O III] 4959: DETECTED with S/N = 10.79
#     ✓ [O III] 5007: DETECTED with S/N = 18.26
#     ✓ H-alpha: DETECTED with S/N = 22.15
#   → Final results plot saved to spectrum_109026.png
# -------------------------------------------------
# Processing Galaxy ID: 10911
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10911.png
#   Found 50 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10938
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10938.png
#   Found 70 significant emission line candidates. Now fitting...
#     ✓ [O III] 5007: DETECTED with S/N = 5.32
#   → Final results plot saved to spectrum_10938.png
# -------------------------------------------------
# Processing Galaxy ID: 10948
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10948.png
#   Found 75 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10953
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10953.png
#   Found 53 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 1096
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_1096.png
#   Found 75 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10974
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10974.png
#   Found 70 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 10988
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_10988.png
#   Found 62 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 110058
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_110058.png
#   Found 72 significant emission line candidates. Now fitting...
#     ✓ H-alpha: DETECTED with S/N = 14.05
#     ✓ He I 10830: DETECTED with S/N = 7.10
#   → Final results plot saved to spectrum_110058.png
# -------------------------------------------------
# Processing Galaxy ID: 11016
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11016.png
#   Found 63 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 1102
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_1102.png
#   Found 47 significant emission line candidates. Now fitting...
#     ✓ [O III] 4959: DETECTED with S/N = 6.78
#     ✓ H-alpha: DETECTED with S/N = 13.91
#   → Final results plot saved to spectrum_1102.png
# -------------------------------------------------
# Processing Galaxy ID: 11034
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11034.png
#   Found 44 significant emission line candidates. Now fitting...
#     ✓ H-alpha: DETECTED with S/N = 16.49
#   → Final results plot saved to spectrum_11034.png
# -------------------------------------------------
# Processing Galaxy ID: 11070
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11070.png
#   Found 64 significant emission line candidates. Now fitting...
#     ✓ [N II] 6583: DETECTED with S/N = 44.32
#     ✓ [S II] 6731: DETECTED with S/N = 7.19
#   → Final results plot saved to spectrum_11070.png
# -------------------------------------------------
# Processing Galaxy ID: 110733
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_110733.png
#   Found 68 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 110742
#   Redshift Correction (Best Match: 'optical' template): Initial z=2.72400 -> Corrected z=2.72329
#   → Continuum diagnostic plot saved to diagnostic_continuum_110742.png
#   Found 7 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 110768
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_110768.png
#   Found 46 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 110793
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_110793.png
#   Found 52 significant emission line candidates. Now fitting...
#     ✓ H-alpha: DETECTED with S/N = 5.48
#   → Final results plot saved to spectrum_110793.png
# -------------------------------------------------
# Processing Galaxy ID: 110852
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_110852.png
#   Found 54 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 11095
#   Could not find redshift for GID 11095 in the master catalog. Skipping.
# -------------------------------------------------
# Processing Galaxy ID: 11118
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11118.png
#   Found 79 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 11184
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11184.png
#   Found 73 significant emission line candidates. Now fitting...
#     ✓ [N II] 6583: DETECTED with S/N = 24.84
#   → Final results plot saved to spectrum_11184.png
# -------------------------------------------------
# Processing Galaxy ID: 11186
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11186.png
#   Found 83 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 11220
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11220.png
#   Found 56 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 11238
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11238.png
#   Found 59 significant emission line candidates. Now fitting...
#     ✓ H-alpha: DETECTED with S/N = 7.34
#   → Final results plot saved to spectrum_11238.png
# -------------------------------------------------
# Processing Galaxy ID: 11266
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11266.png
#   Found 72 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 11269
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11269.png
#   Found 81 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 11274
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11274.png
#   Found 61 significant emission line candidates. Now fitting...
#     ✓ [O III] 4959: DETECTED with S/N = 6.25
#     ✓ [O III] 5007: DETECTED with S/N = 11.67
#     ✓ H-alpha: DETECTED with S/N = 7.55
#   → Final results plot saved to spectrum_11274.png
# -------------------------------------------------
# Processing Galaxy ID: 11340
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11340.png
#   Found 65 significant emission line candidates. Now fitting...
#     ✓ H-alpha: DETECTED with S/N = 28.16
#   → Final results plot saved to spectrum_11340.png
# -------------------------------------------------
# Processing Galaxy ID: 11353
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11353.png
#   Found 58 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 11354
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11354.png
#   Found 76 significant emission line candidates. Now fitting...
#     ✓ [O III] 5007: DETECTED with S/N = 6.10
#   → Final results plot saved to spectrum_11354.png
# -------------------------------------------------
# Processing Galaxy ID: 11355
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11355.png
#   Found 63 significant emission line candidates. Now fitting...
#     ✓ H-beta: DETECTED with S/N = 11.92
#     ✓ [O III] 4959: DETECTED with S/N = 23.42
#     ✓ [O III] 5007: DETECTED with S/N = 33.65
#     ✓ He I 10830: DETECTED with S/N = 13.58
#     ✓ Pa-beta: DETECTED with S/N = 14.08
#     ✓ Pa-alpha: DETECTED with S/N = 15.12
#   → Final results plot saved to spectrum_11355.png
# -------------------------------------------------
# Processing Galaxy ID: 11373
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11373.png
#   Found 47 significant emission line candidates. Now fitting...
#     ✓ [O III] 5007: DETECTED with S/N = 6.12
#   → Final results plot saved to spectrum_11373.png
# -------------------------------------------------
# Processing Galaxy ID: 11444
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11444.png
#   Found 59 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 1146
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_1146.png
#   Found 95 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 11491
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11491.png
#   Found 48 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 11538
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11538.png
#   Found 66 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 11541
#   Could not find redshift for GID 11541 in the master catalog. Skipping.
# -------------------------------------------------
# Processing Galaxy ID: 11547
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11547.png
#   Found 55 significant emission line candidates. Now fitting...
#     ✓ [O II] 3727: DETECTED with S/N = 6.68
#     ✓ H-beta: DETECTED with S/N = 6.22
#     ✓ [O III] 4959: DETECTED with S/N = 9.39
#     ✓ [O III] 5007: DETECTED with S/N = 22.06
#   → Final results plot saved to spectrum_11547.png
# -------------------------------------------------
# Processing Galaxy ID: 11612
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11612.png
#   Found 89 significant emission line candidates. Now fitting...
#     ✓ [O III] 4959: DETECTED with S/N = 6.55
#     ✓ [O III] 5007: DETECTED with S/N = 13.38
#     ✓ H-alpha: DETECTED with S/N = 16.19
#     ✓ Pa-alpha: DETECTED with S/N = 9.45
#   → Final results plot saved to spectrum_11612.png
# -------------------------------------------------
# Processing Galaxy ID: 11626
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11626.png
#   Found 64 significant emission line candidates. Now fitting...
#     ✓ [O II] 3727: DETECTED with S/N = 5.26
#     ✓ H-alpha: DETECTED with S/N = 17.33
#   → Final results plot saved to spectrum_11626.png
# -------------------------------------------------
# Processing Galaxy ID: 11630
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11630.png
#   Found 74 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 11653
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11653.png
#   Found 44 significant emission line candidates. Now fitting...
#     ✓ H-alpha: DETECTED with S/N = 50.60
#     ✓ [S II] 6716: DETECTED with S/N = 12.35
#     ✓ He I 10830: DETECTED with S/N = 6.72
#     ✓ Pa-gamma: DETECTED with S/N = 6.44
#     ✓ Pa-beta: DETECTED with S/N = 15.38
#   → Final results plot saved to spectrum_11653.png
# -------------------------------------------------
# Processing Galaxy ID: 11666
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11666.png
#   Found 86 significant emission line candidates. Now fitting...
#     ✓ [O II] 3727: DETECTED with S/N = 5.62
#     ✓ H-alpha: DETECTED with S/N = 14.79
#     ✓ He I 10830: DETECTED with S/N = 7.71
#   → Final results plot saved to spectrum_11666.png
# -------------------------------------------------
# Processing Galaxy ID: 11677
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11677.png
#   Found 70 significant emission line candidates. Now fitting...
#     ✓ H-alpha: DETECTED with S/N = 14.10
#   → Final results plot saved to spectrum_11677.png
# -------------------------------------------------
# Processing Galaxy ID: 1176
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_1176.png
#   Found 71 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 11764
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11764.png
#   Found 93 significant emission line candidates. Now fitting...
#     ✓ [O III] 4959: DETECTED with S/N = 6.41
#     ✓ [O III] 5007: DETECTED with S/N = 13.91
#   → Final results plot saved to spectrum_11764.png
# -------------------------------------------------
# Processing Galaxy ID: 1177
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_1177.png
#   Found 54 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 11773
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11773.png
#   Found 64 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 11809
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11809.png
#   Found 51 significant emission line candidates. Now fitting...
#     ✓ H-alpha: DETECTED with S/N = 36.52
#     ✓ Pa-epsilon: DETECTED with S/N = 8.45
#     ✓ He I 10830: DETECTED with S/N = 10.83
#   → Final results plot saved to spectrum_11809.png
# -------------------------------------------------
# Processing Galaxy ID: 11848
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11848.png
#   Found 51 significant emission line candidates. Now fitting...
#     ✓ [O II] 3727: DETECTED with S/N = 29.28
#     ✓ [S II] 6716: DETECTED with S/N = 10.08
#     ✓ Pa-beta: DETECTED with S/N = 17.35
#   → Final results plot saved to spectrum_11848.png
# -------------------------------------------------
# Processing Galaxy ID: 11860
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11860.png
#   Found 59 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 11877
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11877.png
#   Found 74 significant emission line candidates. Now fitting...
#     ✓ [O III] 5007: DETECTED with S/N = 8.70
#     ✓ H-alpha: DETECTED with S/N = 14.09
#     ✓ Pa-alpha: DETECTED with S/N = 6.00
#   → Final results plot saved to spectrum_11877.png
# -------------------------------------------------
# Processing Galaxy ID: 11878
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11878.png
#   Found 61 significant emission line candidates. Now fitting...
#     ✓ H-alpha: DETECTED with S/N = 12.94
#   → Final results plot saved to spectrum_11878.png
# -------------------------------------------------
# Processing Galaxy ID: 11890
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11890.png
#   Found 69 significant emission line candidates. Now fitting...
#     ✓ [O II] 3727: DETECTED with S/N = 6.29
#   → Final results plot saved to spectrum_11890.png
# -------------------------------------------------
# Processing Galaxy ID: 11898
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11898.png
#   Found 68 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 11910
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11910.png
#   Found 69 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 11929
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_11929.png
#   Found 91 significant emission line candidates. Now fitting...
#     ✓ H-beta: DETECTED with S/N = 17.03
#     ✓ [O III] 4959: DETECTED with S/N = 26.85
#     ✓ [O III] 5007: DETECTED with S/N = 54.51
#     ✓ H-alpha: DETECTED with S/N = 59.34
#     ✓ [S II] 6716: DETECTED with S/N = 8.22
#   → Final results plot saved to spectrum_11929.png
# -------------------------------------------------
# Processing Galaxy ID: 120414
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_120414.png
#   Found 68 significant emission line candidates. Now fitting...
#     ✓ [O II] 3727: DETECTED with S/N = 19.95
#     ✓ [Ne III] 3869: DETECTED with S/N = 6.88
#     ✓ H-delta: DETECTED with S/N = 6.20
#     ✓ H-gamma: DETECTED with S/N = 11.35
#     ✓ H-beta: DETECTED with S/N = 33.86
#     ✓ [O III] 4959: DETECTED with S/N = 44.26
#     ✓ [O III] 5007: DETECTED with S/N = 20.75
#     ✓ He I 10830: DETECTED with S/N = 41.32
# ...
#     ✓ H-alpha: DETECTED with S/N = 36.55
#   → Final results plot saved to spectrum_13322.png
# -------------------------------------------------
# Processing Galaxy ID: 13328
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13328.png
#   Found 69 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 13329
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13329.png
#   Found 64 significant emission line candidates. Now fitting...
#     ✓ H-beta: DETECTED with S/N = 7.54
#     ✓ [O III] 4959: DETECTED with S/N = 13.31
#     ✓ [O III] 5007: DETECTED with S/N = 31.08
#     ✓ H-alpha: DETECTED with S/N = 25.79
#   → Final results plot saved to spectrum_13329.png
# -------------------------------------------------
# Processing Galaxy ID: 13340
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13340.png
#   Found 68 significant emission line candidates. Now fitting...
#     ✓ H-beta: DETECTED with S/N = 9.14
#     ✓ [O III] 4959: DETECTED with S/N = 16.74
#     ✓ [O III] 5007: DETECTED with S/N = 32.99
#     ✓ H-alpha: DETECTED with S/N = 29.79
#     ✓ [S II] 6716: DETECTED with S/N = 5.20
#   → Final results plot saved to spectrum_13340.png
# -------------------------------------------------
# Processing Galaxy ID: 13341
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13341.png
#   Found 61 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 13347
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13347.png
#   Found 46 significant emission line candidates. Now fitting...
#     ✓ [N II] 6583: DETECTED with S/N = 13.78
#   → Final results plot saved to spectrum_13347.png
# -------------------------------------------------
# Processing Galaxy ID: 13348
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13348.png
#   Found 76 significant emission line candidates. Now fitting...
#     ✓ [O III] 4959: DETECTED with S/N = 10.50
#     ✓ [O III] 5007: DETECTED with S/N = 20.70
#   → Final results plot saved to spectrum_13348.png
# -------------------------------------------------
# Processing Galaxy ID: 13361
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13361.png
#   Found 79 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 133653
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_133653.png
#   Found 47 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 13369
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13369.png
#   Found 83 significant emission line candidates. Now fitting...
#     ✓ H-beta: DETECTED with S/N = 23.82
#     ✓ [O III] 4959: DETECTED with S/N = 39.89
#     ✓ [O III] 5007: DETECTED with S/N = 73.61
#     ✓ He I 10830: DETECTED with S/N = 10.04
#   → Final results plot saved to spectrum_13369.png
# -------------------------------------------------
# Processing Galaxy ID: 133718
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_133718.png
#   Found 58 significant emission line candidates. Now fitting...
#     ✓ [O III] 4959: DETECTED with S/N = 5.34
#     ✓ [O III] 5007: DETECTED with S/N = 11.45
#     ✓ H-alpha: DETECTED with S/N = 6.57
#   → Final results plot saved to spectrum_133718.png
# -------------------------------------------------
# Processing Galaxy ID: 13385
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13385.png
#   Found 62 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 134136
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_134136.png
#   Found 51 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 13434
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13434.png
#   Found 69 significant emission line candidates. Now fitting...
#     ✓ [O III] 5007: DETECTED with S/N = 6.20
#   → Final results plot saved to spectrum_13434.png
# -------------------------------------------------
# Processing Galaxy ID: 13437
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13437.png
#   Found 83 significant emission line candidates. Now fitting...
#     ✓ [O II] 3727: DETECTED with S/N = 9.40
#     ✓ [Ne III] 3869: DETECTED with S/N = 6.20
#     ✓ H-gamma: DETECTED with S/N = 6.49
#     ✓ [O III] 4959: DETECTED with S/N = 33.11
#     ✓ [O III] 5007: DETECTED with S/N = 47.83
#     ✓ He I 5875: DETECTED with S/N = 5.43
#     ✓ H-alpha: DETECTED with S/N = 45.84
#   → Final results plot saved to spectrum_13437.png
#   >>> AGN/HIGH-IONIZATION SIGNATURE DETECTED! Flagged lines: ['[Ne III] 3869']
# -------------------------------------------------
# Processing Galaxy ID: 134419
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_134419.png
#   Found 59 significant emission line candidates. Now fitting...
#     ✓ H-alpha: DETECTED with S/N = 15.55
#   → Final results plot saved to spectrum_134419.png
# -------------------------------------------------
# Processing Galaxy ID: 134422
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_134422.png
#   Found 74 significant emission line candidates. Now fitting...
#     ✓ H-beta: DETECTED with S/N = 8.85
#     ✓ [O III] 4959: DETECTED with S/N = 10.16
#     ✓ [O III] 5007: DETECTED with S/N = 25.68
#   → Final results plot saved to spectrum_134422.png
# -------------------------------------------------
# Processing Galaxy ID: 13507
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13507.png
#   Found 66 significant emission line candidates. Now fitting...
#     ✓ [O III] 5007: DETECTED with S/N = 6.69
#     ✓ H-alpha: DETECTED with S/N = 6.96
#   → Final results plot saved to spectrum_13507.png
# -------------------------------------------------
# Processing Galaxy ID: 135134
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_135134.png
#   Found 40 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 13519
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13519.png
#   Found 69 significant emission line candidates. Now fitting...
#     ✓ H-beta: DETECTED with S/N = 6.22
#     ✓ [O III] 4959: DETECTED with S/N = 12.46
#     ✓ [O III] 5007: DETECTED with S/N = 29.25
#     ✓ H-alpha: DETECTED with S/N = 22.84
#   → Final results plot saved to spectrum_13519.png
# -------------------------------------------------
# Processing Galaxy ID: 13520
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13520.png
#   Found 69 significant emission line candidates. Now fitting...
#     ✓ [O II] 3727: DETECTED with S/N = 14.97
#     ✓ [Ne III] 3869: DETECTED with S/N = 8.25
#     ✓ H-gamma: DETECTED with S/N = 10.04
#     ✓ [O III] 4959: DETECTED with S/N = 36.11
#     ✓ [O III] 5007: DETECTED with S/N = 66.30
#     ✓ H-alpha: DETECTED with S/N = 39.80
#   → Final results plot saved to spectrum_13520.png
#   >>> AGN/HIGH-IONIZATION SIGNATURE DETECTED! Flagged lines: ['[Ne III] 3869']
# -------------------------------------------------
# Processing Galaxy ID: 13525
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13525.png
#   Found 71 significant emission line candidates. Now fitting...
#     ✓ [O II] 3727: DETECTED with S/N = 6.96
#     ✓ [O III] 5007: DETECTED with S/N = 40.82
#     ✓ H-alpha: DETECTED with S/N = 18.46
#   → Final results plot saved to spectrum_13525.png
# -------------------------------------------------
# Processing Galaxy ID: 13534
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13534.png
#   Found 60 significant emission line candidates. Now fitting...
#     ✓ H-alpha: DETECTED with S/N = 12.81
#   → Final results plot saved to spectrum_13534.png
# -------------------------------------------------
# Processing Galaxy ID: 13543
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13543.png
#   Found 72 significant emission line candidates. Now fitting...
#     ✓ [O III] 5007: DETECTED with S/N = 6.91
#   → Final results plot saved to spectrum_13543.png
# -------------------------------------------------
# Processing Galaxy ID: 13552
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13552.png
#   Found 62 significant emission line candidates. Now fitting...
#     ✓ H-beta: DETECTED with S/N = 8.15
#     ✓ [O III] 4959: DETECTED with S/N = 14.05
#     ✓ [O III] 5007: DETECTED with S/N = 21.35
#   → Final results plot saved to spectrum_13552.png
# -------------------------------------------------
# Processing Galaxy ID: 13556
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13556.png
#   Found 74 significant emission line candidates. Now fitting...
#     ✓ [N II] 6583: DETECTED with S/N = 7.44
#   → Final results plot saved to spectrum_13556.png
# -------------------------------------------------
# Processing Galaxy ID: 13560
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13560.png
#   Found 63 significant emission line candidates. Now fitting...
#     ✓ H-beta: DETECTED with S/N = 6.57
#     ✓ [O III] 4959: DETECTED with S/N = 10.85
#     ✓ H-alpha: DETECTED with S/N = 17.00
#   → Final results plot saved to spectrum_13560.png
# -------------------------------------------------
# Processing Galaxy ID: 13561
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13561.png
#   Found 59 significant emission line candidates. Now fitting...
#     ✓ [O III] 5007: DETECTED with S/N = 5.68
#   → Final results plot saved to spectrum_13561.png
# -------------------------------------------------
# Processing Galaxy ID: 13567
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13567.png
#   Found 65 significant emission line candidates. Now fitting...
#     ✓ [O II] 3727: DETECTED with S/N = 6.97
#     ✓ H-beta: DETECTED with S/N = 10.58
#     ✓ [O III] 4959: DETECTED with S/N = 20.26
#     ✓ [O III] 5007: DETECTED with S/N = 44.70
#     ✓ H-alpha: DETECTED with S/N = 30.64
#   → Final results plot saved to spectrum_13567.png
# -------------------------------------------------
# Processing Galaxy ID: 13592
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13592.png
#   Found 62 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 13596
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13596.png
#   Found 63 significant emission line candidates. Now fitting...
#     ✓ H-delta: DETECTED with S/N = 5.48
#     ✓ H-gamma: DETECTED with S/N = 8.66
#     ✓ H-beta: DETECTED with S/N = 19.91
#     ✓ [O III] 4959: DETECTED with S/N = 31.26
#     ✓ [O III] 5007: DETECTED with S/N = 58.78
#     ✓ [N II] 6583: DETECTED with S/N = 11.65
#   → Final results plot saved to spectrum_13596.png
# -------------------------------------------------
# Processing Galaxy ID: 13605
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13605.png
#   Found 79 significant emission line candidates. Now fitting...
#     ✓ [C III] 1909: DETECTED with S/N = 22.21
#     ✓ H-beta: DETECTED with S/N = 8.07
#     ✓ [O III] 4959: DETECTED with S/N = 13.56
#     ✓ [O III] 5007: DETECTED with S/N = 23.82
#     ✓ H-alpha: DETECTED with S/N = 25.74
#   → Final results plot saved to spectrum_13605.png
#   >>> AGN/HIGH-IONIZATION SIGNATURE DETECTED! Flagged lines: ['[C III] 1909']
# -------------------------------------------------
# Processing Galaxy ID: 13607
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13607.png
#   Found 75 significant emission line candidates. Now fitting...
#     ✓ [N II] 6583: DETECTED with S/N = 5.11
#   → Final results plot saved to spectrum_13607.png
# -------------------------------------------------
# Processing Galaxy ID: 13612
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13612.png
#   Found 63 significant emission line candidates. Now fitting...
#     ✓ [N II] 6583: DETECTED with S/N = 8.41
#   → Final results plot saved to spectrum_13612.png
# -------------------------------------------------
# Processing Galaxy ID: 13618
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13618.png
#   Found 65 significant emission line candidates. Now fitting...
#     ✓ [O III] 5007: DETECTED with S/N = 10.87
#     ✓ H-alpha: DETECTED with S/N = 6.69
#   → Final results plot saved to spectrum_13618.png
# -------------------------------------------------
# Processing Galaxy ID: 13620
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13620.png
#   Found 102 significant emission line candidates. Now fitting...
#     ✓ H-beta: DETECTED with S/N = 5.50
#     ✓ [O III] 4959: DETECTED with S/N = 11.62
#     ✓ [O III] 5007: DETECTED with S/N = 31.95
#     ✓ H-alpha: DETECTED with S/N = 19.99
#   → Final results plot saved to spectrum_13620.png
# -------------------------------------------------
# Processing Galaxy ID: 13630
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13630.png
#   Found 57 significant emission line candidates. Now fitting...
#     ✓ [O III] 4959: DETECTED with S/N = 10.29
#     ✓ [O III] 5007: DETECTED with S/N = 14.60
#     ✓ H-alpha: DETECTED with S/N = 17.63
#   → Final results plot saved to spectrum_13630.png
# -------------------------------------------------
# Processing Galaxy ID: 13634
#   Cross-correlation failed for all templates. Using initial redshift.
#   → Continuum diagnostic plot saved to diagnostic_continuum_13634.png
#   Found 64 significant emission line candidates. Now fitting...
# -------------------------------------------------
# Processing Galaxy ID: 13638
#   Cross-correlation failed for all templates. Using initial redshift.
